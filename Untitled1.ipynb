# %%
# %%writefile .env
# TOMTOM_API_KEY=kNMMXwqUlXLF5oL2Gxc3Lz2gpxdNGLUT
# Out:
# Writing .env

# %%
import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Fetch the variable
key = os.getenv("TOMTOM_API_KEY")

if key:
    print("✅ .env loaded successfully! Key starting with:", key[:5] + "...")
else:
    print("❌ Failed to load .env file. Check if it is in the same folder as this notebook.")
# Out:
# ✅ .env loaded successfully! Key starting with: kNMMX...
