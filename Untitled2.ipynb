# %%
# %%writefile .gitignore
# # Ignore API keys and secrets
# .env
# *.env
#
# # Ignore Virtual Environment
# venv/
# .venv/
# env/
#
# # Ignore Python cache & checkpoints
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# Out:
# Writing .gitignore

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/NIKHIL.P/smart_traffic_durg_raipur/.git/

# %%
# !git config --global user.name "Nikhil P"
# !git config --global user.email "your_email@example.com"
